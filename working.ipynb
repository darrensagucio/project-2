# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
engine = create_engine

# %%
epa_data = pd.read_csv('static/data/MASTER epa_material_generation_recycling_1960-2018_0.csv')
mmg_data = pd.read_csv('static/data/MASTER Combined MMG2009-2019 Data.csv')
pop_data = pd.read_csv('static/data/populationdata1950-2019.csv')

# %%
epa_data = epa_data[['Year', 'Food Generated (thousand tons)']]
mmg_data = mmg_data[['State Name', 'State Abbreviation ', 'Year', 'Food Insecurity Rate (aggregate of counties)',
                    ' Estimated Number Food Insecure Individuals ', 'Low Threshold in state', 'Low Threshold Type',
                    'High Threshold in state', 'High Threshold Type', '% FI ? Low Threshold', '% FI Btwn Thresholds',
                     '% FI > High Threshold', 'Weighted Annual Dollars ', ' Cost Per Meal ', 'Child Food Insecurity Rate (aggregate of counties)',
                     ' Number Food Insecure Children (aggregate of counties) ', '% of children in FI HH with incomes at or below 185% FPL',
                    '% of children in FI HH with incomes above 185% FPL',
                     'Population']]

# %%
mmg_data
# Out:
#     State Name State Abbreviation   Year  \
# 0       Alaska                  AK  2009
# 1       Alaska                  AK  2010
# 2       Alaska                  AK  2011
# 3       Alaska                  AK  2012
# 4       Alaska                  AK  2013
# ..         ...                 ...   ...
# 556    Wyoming                  WY  2015
# 557    Wyoming                  WY  2016
# 558    Wyoming                  WY  2017
# 559    Wyoming                  WY  2018
# 560    Wyoming                  WY  2019
#
#      Food Insecurity Rate (aggregate of counties)  \
# 0                                           0.135
# 1                                           0.146
# 2                                           0.147
# 3                                           0.140
# 4                                           0.142
# ..                                            ...
# 556                                         0.123
# 557                                         0.126
# ...

# %%
epa_data
# Out:
#                                                  Year  \
# 0                                                1960
# 1                                                1961
# 2                                                1962
# 3                                                1963
# 4                                                1964
# ..                                                ...
# 59                                                NaN
# 60                                  Neg. = negligible
# 61  * All other includes rubber, leather, textiles...
# 62                                                NaN
# 63  Source: U.S. EPA. Advancing Sustainable Materi...
#
#     Food Generated (thousand tons)
# 0                          12200.0
# 1                          12500.0
# 2                          12600.0
# 3                          12700.0
# 4                          12700.0
# ..                             ...
# 59                             NaN
# ...
